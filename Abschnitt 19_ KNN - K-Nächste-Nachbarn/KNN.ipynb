# %% [markdown]
# # Daten importieren
# *Datenquelle: [https://www.kaggle.com/datasets/gabrielsantello/cars-purchase-decision-dataset](https://www.kaggle.com/datasets/gabrielsantello/cars-purchase-decision-dataset)*

# %%
import pandas as pd

df = pd.read_csv("car_data.csv")
df
# Out:
#      Age  AnnualSalary  Purchased
# 0     54        136500      False
# 1     41         67500      False
# 2     50         29500       True
# 3     20         86000      False
# 4     27         31500      False
# ..   ...           ...        ...
# 145   63         36500       True
# 146   38         61000      False
# 147   23         28000      False
# 148   49         43500       True
# 149   44        113500       True
#
# [150 rows x 3 columns]

# %% [markdown]
# # Daten aufteilen

# %%
X = df.copy()
y = X.pop("Purchased")

# %%
X
# Out:
#      Age  AnnualSalary
# 0     54        136500
# 1     41         67500
# 2     50         29500
# 3     20         86000
# 4     27         31500
# ..   ...           ...
# 145   63         36500
# 146   38         61000
# 147   23         28000
# 148   49         43500
# 149   44        113500
#
# [150 rows x 2 columns]

# %%
y
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 145     True
# 146    False
# 147    False
# 148     True
# 149     True
# Name: Purchased, Length: 150, dtype: bool

# %%
y.value_counts() / len(y)
# Out:
# False    0.62
# True     0.38
# Name: Purchased, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=0)

# %%
X_train.describe()
# Out:
#               Age   AnnualSalary
# count  120.000000     120.000000
# mean    39.433333   70712.500000
# std     10.809841   33096.603097
# min     18.000000   15000.000000
# 25%     32.750000   44500.000000
# 50%     40.000000   70500.000000
# 75%     47.000000   88375.000000
# max     63.000000  150500.000000

# %%
X_test.describe()
# Out:
#              Age   AnnualSalary
# count  30.000000      30.000000
# mean   38.966667   68050.000000
# std    11.772215   28573.061222
# min    19.000000   16500.000000
# 25%    28.000000   42500.000000
# 50%    38.500000   71500.000000
# 75%    47.000000   83500.000000
# max    62.000000  137000.000000

# %% [markdown]
# # Daten skalieren

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
scaler.transform(X_train)
# Out:
# array([[-0.22604736,  1.72300473],
#        [-0.41183972, -0.32503083],
#        [ 0.88870675, -0.82566174],
#        [ 0.14553734,  0.05423502],
#        [ 0.05264117, -0.32503083],
#        [-0.50473589, -0.79532048],
#        [ 0.42422587,  1.29822699],
#        [ 0.42422587, -0.24917766],
#        [ 0.23843352, -0.50707843],
#        [ 0.05264117,  0.13008818],
#        [-0.31894354,  0.17560009],
#        [-0.22604736, -0.56776097],
#        [ 0.14553734, -0.09747132],
#        [-0.41183972, -1.34146329],
#        [-1.99107471, -0.81049111],
#        [ 0.7029144 , -0.59810224],
#        [-1.15500913,  0.35764769],
#        [ 1.44608381,  0.02389375],
#        [-1.2479053 ,  0.29696516],
#        [-1.34080148,  0.28179452],
#        [ 0.7029144 , -0.65878477],
#        [ 1.35318764,  1.99607614],
#        [ 0.05264117,  0.81276671],
#        [ 1.53897999,  2.26914755],
#        [-1.15500913, -0.79532048],
#        [-0.59763207, -0.32503083],
#        [ 1.53897999,  0.41833023],
#        [-1.80528236,  0.46384213],
#        [ 1.63187617,  0.05423502],
#        [-1.99107471,  0.34247706],
#        [-0.13315119,  0.14525882],
#        [ 0.05264117,  1.60163966],
#        [-0.96921677,  0.47901276],
#        [ 0.88870675,  2.13261184],
#        [-0.41183972,  0.08457628],
#        [ 1.81766852,  0.96447304],
#        [-0.13315119, -0.37054273],
#        [ 0.88870675,  0.81276671],
#        [ 1.91056469, -0.87117365],
#        [-0.78342442, -1.58419343],
#        [-0.13315119,  2.26914755],
#        [-0.31894354, -0.23400703],
#        [ 1.16739528, -0.09747132],
#        [ 1.72477234,  1.72300473],
#        [ 0.23843352, -0.5374197 ],
#        [-0.22604736, -1.09873315],
#        [-0.41183972, -1.477999  ],
#        [ 0.23843352,  1.13135001],
#        [ 1.07449911,  0.66106037],
#        [ 0.7029144 , -1.53868153],
#        [-0.13315119,  0.00872311],
#        [ 1.07449911, -0.76497921],
#        [ 0.7029144 , -1.4324871 ],
#        [-1.06211295,  0.57003656],
#        [ 0.61001823,  1.32856825],
#        [ 0.23843352,  1.99607614],
#        [-1.43369766, -1.49316963],
#        [-0.04025501, -0.24917766],
#        [ 0.79581058, -0.55259034],
#        [-1.15500913,  0.5852072 ],
#        [-1.15500913,  0.44867149],
#        [-1.34080148, -0.34020146],
#        [-0.04025501, -0.3098602 ],
#        [-0.13315119, -0.29468956],
#        [ 1.07449911,  0.84310797],
#        [ 0.05264117,  0.05423502],
#        [ 1.07449911, -1.00770935],
#        [ 0.14553734,  1.14652065],
#        [-0.04025501, -0.87117365],
#        [-0.04025501,  1.72300473],
#        [ 0.05264117, -0.82566174],
#        [-0.22604736,  0.13008818],
#        [ 0.79581058,  0.7672548 ],
#        [ 1.63187617,  1.93539361],
#        [-1.80528236, -1.05322125],
#        [-0.8763206 , -1.69038787],
#        [-0.8763206 ,  0.41833023],
#        [ 0.23843352,  1.14652065],
#        [ 0.23843352, -0.17332449],
#        [-0.78342442,  0.32730642],
#        [-1.2479053 , -1.62970533],
#        [-0.31894354, -0.67395541],
#        [ 1.35318764,  1.00998494],
#        [ 0.61001823, -1.12907442],
#        [ 1.26029146,  0.03906438],
#        [-0.13315119, -0.29468956],
#        [-0.13315119, -1.09873315],
#        [-1.15500913, -1.18975695],
#        [ 0.98160293,  1.17686192],
#        [ 0.23843352,  0.32730642],
#        [ 0.98160293, -0.81049111],
#        [ 0.14553734, -0.37054273],
#        [ 1.72477234,  0.14525882],
#        [-0.13315119,  0.7217429 ],
#        [ 0.61001823, -1.477999  ],
#        [ 0.23843352,  0.20594135],
#        [-1.80528236, -1.34146329],
#        [-0.13315119, -0.4919078 ],
#        [ 0.3313297 ,  0.11491755],
#        [ 0.7029144 ,  0.81276671],
#        [-0.41183972, -0.79532048],
#        [-1.61949001,  0.08457628],
#        [ 0.88870675, -1.05322125],
#        [ 1.72477234, -0.99253872],
#        [ 2.18925322, -1.03805062],
#        [-1.89817854, -1.50834026],
#        [ 0.98160293,  0.52452466],
#        [-0.69052824, -0.09747132],
#        [ 0.05264117,  0.29696516],
#        [-1.2479053 ,  0.28179452],
#        [-1.89817854, -0.02161815],
#        [-0.50473589,  2.42085389],
#        [ 0.14553734,  0.08457628],
#        [-1.06211295, -0.34020146],
#        [-1.52659383, -1.28078076],
#        [-1.80528236, -1.46282836],
#        [-0.59763207,  1.44993332],
#        [ 1.44608381,  2.11744121],
#        [-1.52659383, -1.29595139],
#        [ 0.51712205, -0.46156653]])

# %%
X_train_scaled = pd.DataFrame(scaler.transform(X_train), columns=X_train.columns, index=X_train.index)
X_test_scaled = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns, index=X_test.index)

# %%
X_train_scaled
# Out:
#           Age  AnnualSalary
# 81  -0.226047      1.723005
# 85  -0.411840     -0.325031
# 148  0.888707     -0.825662
# 25   0.145537      0.054235
# 80   0.052641     -0.325031
# ..        ...           ...
# 116 -1.805282     -1.462828
# 101 -0.597632      1.449933
# 24   1.446084      2.117441
# 147 -1.526594     -1.295951
# 111  0.517122     -0.461567
#
# [120 rows x 2 columns]

# %%
X_test_scaled
# Out:
#           Age  AnnualSalary
# 19  -0.504736     -1.159416
# 68  -1.155009     -1.038051
# 105  0.052641      0.357648
# 13  -1.155009     -1.204928
# 138  0.702914      0.387989
# 141 -0.226047     -0.416055
# 86   2.096357      0.600378
# 53  -0.133151     -0.173324
# 95   1.260291     -0.947027
# 112 -1.898179     -0.036789
# 114 -1.712386      0.387989
# 54   0.145537     -0.522249
# 65  -0.040255     -0.249178
# 133  1.910565      1.844370
# 10   0.702914      0.296965
# 42   1.353188     -1.068392
# 106 -0.226047      0.175600
# 69   0.145537     -0.673955
# 33  -1.155009      0.524525
# 2    0.981603     -1.250439
# 90   0.331330      0.205941
# 109 -1.155009     -1.644876
# 134 -1.062113      0.812767
# 142  1.538980     -0.916686
# 93  -0.040255      0.130088
# 131 -1.062113      0.433501
# 136 -1.155009      2.011247
# 58  -0.783424      0.008723
# 37  -0.504736      0.039064
# 115  1.446084      0.661060

# %%
X_train_scaled.describe()
# Out:
#                 Age  AnnualSalary
# count  1.200000e+02  1.200000e+02
# mean   2.960595e-16  7.401487e-18
# std    1.004193e+00  1.004193e+00
# min   -1.991075e+00 -1.690388e+00
# 25%   -6.208561e-01 -7.953205e-01
# 50%    5.264117e-02 -6.447519e-03
# 75%    7.029144e-01  5.359026e-01
# max    2.189253e+00  2.420854e+00

# %%
X_test_scaled.describe()
# Out:
#              Age  AnnualSalary
# count  30.000000     30.000000
# mean   -0.043352     -0.080784
# std     1.093594      0.866943
# min    -1.898179     -1.644876
# 25%    -1.062113     -0.856003
# 50%    -0.086703      0.023894
# 75%     0.702914      0.387989
# max     2.096357      2.011247

# %% [markdown]
# # Trainingsdaten visualisieren

# %%
import seaborn as sns

sns.scatterplot(x=X_train_scaled["Age"], y=X_train_scaled["AnnualSalary"], hue=y_train)
# Out:
# <Axes: xlabel='Age', ylabel='AnnualSalary'>

# %% [markdown]
# # Beispielmodell trainieren

# %%
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier(n_neighbors=1)
model.fit(X_train_scaled, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %% [markdown]
# # KNN-Classifier - Entscheidungsgrenze visualisieren

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

def plot_decision_boundaries(model, feature_1, feature_2, target):
    # Grenzen des Plots basierend auf den Merkmalen definieren
    x_min, x_max = feature_1.min() - 1, feature_1.max() + 1
    y_min, y_max = feature_2.min() - 1, feature_2.max() + 1

    # Ein Gitter von Punkten mit einem Abstand von 0.03 zwischen ihnen erstellen
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.03), np.arange(y_min, y_max, 0.03))

    # Vorhersagen für jeden Punkt im Gitter generieren und die Form der Ausgabe anpassen
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    # Hintergrund des Plots mit den Vorhersagen färben
    plt.pcolormesh(xx, yy, Z, cmap=ListedColormap(["lightblue", "lightcoral"]))

    # Scatterplot der tatsächlichen Datenpunkte
    sns.scatterplot(x=feature_1, y=feature_2, hue=target)

    # Beschriftung der Achsen und Titel
    plt.xlabel(feature_1.name)
    plt.ylabel(feature_2.name)
    plt.title("Entscheidungsgrenze")

# %%
plot_decision_boundaries(model, X_train_scaled["Age"], X_train_scaled["AnnualSalary"], y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # KNN-Classifier - Hyperparameteroptimierung

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_neighbors': [3, 5, 7, 9]
}

grid_search = GridSearchCV(model, param_grid, cv=4, scoring='accuracy')
grid_search.fit(X_train_scaled, y_train)

print("Best Accuracy: ", grid_search.best_score_)
print("Best Parameter: ", grid_search.best_params_)
# Out:
# Best Accuracy:  0.9
# Best Parameter:  {'n_neighbors': 5}

# %%
final_model = grid_search.best_estimator_

plot_decision_boundaries(final_model, X_train_scaled["Age"], X_train_scaled["AnnualSalary"], y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Finale Accuracy

# %%
from sklearn.metrics import accuracy_score

y_predict = final_model.predict(X_test_scaled)

accuracy = accuracy_score(y_test, y_predict)
print("Final Accuracy:", accuracy)
# Out:
# Final Accuracy: 0.9

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_predictions(y_test, y_predict)

# %%
plot_decision_boundaries(final_model, X_test_scaled["Age"], X_test_scaled["AnnualSalary"], y_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
