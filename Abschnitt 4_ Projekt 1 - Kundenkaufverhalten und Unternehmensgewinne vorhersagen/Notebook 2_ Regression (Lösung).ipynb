# %% [markdown]
# # Daten importieren

# %%
import pandas as pd

# Schritt 1: Lese die entsprechende Datei ein, speichere die Daten in der Variable 'df' ab und gib sie anschließend aus.
df = pd.read_csv("stores_profit_data.csv")
df
# Out:
#     Number_of_Stores   Profit
# 0                 45  2322039
# 1                 48  2599271
# 2                 65  3263434
# 3                 68  3927918
# 4                 68  3363408
# ..               ...      ...
# 95                86  4588423
# 96                49  2480000
# 97                50  2756896
# 98                70  3171411
# 99                42  1759510
#
# [100 rows x 2 columns]

# %% [markdown]
# # Daten visualisieren

# %%
import seaborn as sns

# Schritt 2: Visualisiere die Daten mithilfe eines Scatterplots.
sns.scatterplot(x=df["Number_of_Stores"], y=df["Profit"])
# Out:
# <Axes: xlabel='Number_of_Stores', ylabel='Profit'>

# %% [markdown]
# # Daten aufteilen

# %%
# Schritt 3: Weise das entsprechende Feature der Eingabevariable X und das zugehörige Ziel der Zielvariable y zu.

X = df[["Number_of_Stores"]]
y = df["Profit"]

# %%
X
# Out:
#     Number_of_Stores
# 0                 45
# 1                 48
# 2                 65
# 3                 68
# 4                 68
# ..               ...
# 95                86
# 96                49
# 97                50
# 98                70
# 99                42
#
# [100 rows x 1 columns]

# %%
y
# Out:
# 0     2322039
# 1     2599271
# 2     3263434
# 3     3927918
# 4     3363408
#        ...
# 95    4588423
# 96    2480000
# 97    2756896
# 98    3171411
# 99    1759510
# Name: Profit, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split

#Schritt 4: Unterteile die Daten in Trainings- und Testdaten, wobei die Testdaten 20% der Gesamtdaten ausmachen sollten.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_test
# Out:
#     Number_of_Stores
# 26                21
# 86                77
# 2                 65
# 55                37
# 75                15
# 93                80
# 16                40
# 73                92
# 54                 1
# 95                86
# 53                 1
# 92                24
# 78                43
# 13                13
# 7                 22
# 30                48
# 22                26
# 24                73
# 33                89
# 8                 37

# %%
y_test
# Out:
# 26    1918599
# 86    3920908
# 2     3263434
# 55    1103330
# 75    -178543
# 93    3421859
# 16    1887980
# 73    4469322
# 54    -360431
# 95    4588423
# 53     -74710
# 92    1644877
# 78    1760101
# 13     -67914
# 7      918366
# 30    2110545
# 22     684682
# 24    3150808
# 33    4844833
# 8     1843827
# Name: Profit, dtype: int64

# %% [markdown]
# # Modell trainieren

# %%
from sklearn.linear_model import LinearRegression

# Schritt 5: Erstelle eine Instanz eines linearen Regressionsmodells und trainiere dieses Modell auf den Trainingsdaten.
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Modell visualisieren

# %%
# Schritt 6: Visualisiere das Modell mithilfe eines Regplots.

sns.regplot(x=X_train, y=y_train, ci=None)
# Out:
# <Axes: xlabel='Number_of_Stores', ylabel='Profit'>

# %% [markdown]
# # Vorhersage

# %%
# Schritt 7: Nutze das trainierte Modell, um Vorhersagen für die Testdaten zu generieren.

y_predict = model.predict(X_test)

# %% [markdown]
# # Modellbewertung (Mean Absolute Error)

# %%
from sklearn.metrics import mean_absolute_error

# Schritt 8: Berechne den Mean Absolute Error (MAE) basierend auf den Vorhersagen und den Testdaten und vervollständige die 'print()'-Funktion.
mae = mean_absolute_error(y_predict, y_test)
print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 390048.21768033726

# %% [markdown]
# # Modellparameter

# %%
# Schritt 9: Extrahiere die Steigung 'm' und den y-Achsenabschnitt 'c' des trainierten Modells und vervollständige die beiden 'print()'-Funktionen.

m = model.coef_[0]
c = model.intercept_

print("Steigung: ", m)
print("y-Achsenabschnitt: ", c)
# Out:
# Steigung:  50618.53056394633
# y-Achsenabschnitt:  -16710.469332137145
