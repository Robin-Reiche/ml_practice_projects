# %% [markdown]
# # Daten importieren

# %%
import pandas as pd

# Schritt 1: Lese die entsprechende Datei ein, speichere die Daten in der Variable 'df' ab und gib sie anschließend aus.
df = pd.read_csv("purchasing_behavior_data.csv")
df
# Out:
#     Minutes_Spent  Purchase_Made
# 0              15           True
# 1              20           True
# 2              10          False
# 3              25           True
# 4               3          False
# 5              18           True
# 6              30          False
# 7               8          False
# 8              22           True
# 9              14           True
# 10              9          False
# 11              6          False
# 12             13           True
# 13              7          False
# 14              4           True
# 15              5          False
# 16             22           True
# 17              1          False
# 18             30          False
# 19             11           True

# %%
# Schritt 2: Zeige die Häufigkeit jeder Klasse an, indem du '.value_counts()' verwendest.

df["Purchase_Made"].value_counts()
# Out:
# True     10
# False    10
# Name: Purchase_Made, dtype: int64

# %% [markdown]
# # Daten visualisieren

# %%
import seaborn as sns

# Schritt 3: Visualisiere die Daten mithilfe eines Scatterplots.
sns.scatterplot(x=df["Minutes_Spent"], y=df["Purchase_Made"])
# Out:
# <Axes: xlabel='Minutes_Spent', ylabel='Purchase_Made'>

# %% [markdown]
# # Daten aufteilen

# %%
# Schritt 4: Weise das entsprechende Feature der Eingabevariable X und das zugehörige Ziel der Zielvariable y zu.

X = df[["Minutes_Spent"]]
y = df["Purchase_Made"]

# %%
X
# Out:
#     Minutes_Spent
# 0              15
# 1              20
# 2              10
# 3              25
# 4               3
# 5              18
# 6              30
# 7               8
# 8              22
# 9              14
# 10              9
# 11              6
# 12             13
# 13              7
# 14              4
# 15              5
# 16             22
# 17              1
# 18             30
# 19             11

# %%
y
# Out:
# 0      True
# 1      True
# 2     False
# 3      True
# 4     False
# 5      True
# 6     False
# 7     False
# 8      True
# 9      True
# 10    False
# 11    False
# 12     True
# 13    False
# 14     True
# 15    False
# 16     True
# 17    False
# 18    False
# 19     True
# Name: Purchase_Made, dtype: bool

# %%
from sklearn.model_selection import train_test_split

#Schritt 5: Unterteile die Daten in Trainings- und Testdaten, wobei die Testdaten 20% der Gesamtdaten ausmachen sollten.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_train
# Out:
#     Minutes_Spent
# 10              9
# 17              1
# 6              30
# 13              7
# 4               3
# 2              10
# 5              18
# 14              4
# 9              14
# 7               8
# 16             22
# 11              6
# 3              25
# 0              15
# 15              5
# 12             13

# %%
y_train
# Out:
# 10    False
# 17    False
# 6     False
# 13    False
# 4     False
# 2     False
# 5      True
# 14     True
# 9      True
# 7     False
# 16     True
# 11    False
# 3      True
# 0      True
# 15    False
# 12     True
# Name: Purchase_Made, dtype: bool

# %% [markdown]
# # Modell trainieren

# %%
from sklearn.tree import DecisionTreeClassifier

# Schritt 6: Erstelle eine Instanz eines Entscheidungsbaums und trainiere dieses Modell auf den Trainingsdaten.
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# # Modell visualisieren

# %%
from sklearn.tree import plot_tree

# Schritt 7: Visualisiere das Modell mithilfe von 'plot_tree()'.
plot_tree(model, feature_names=["Minutes_Spent"])
# Out:
# [Text(0.5555555555555556, 0.875, 'Minutes_Spent <= 11.5\ngini = 0.492\nsamples = 16\nvalue = [9, 7]'),
#  Text(0.3333333333333333, 0.625, 'Minutes_Spent <= 4.5\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.2222222222222222, 0.375, 'Minutes_Spent <= 3.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.1111111111111111, 0.125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3333333333333333, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4444444444444444, 0.375, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.7777777777777778, 0.625, 'Minutes_Spent <= 27.5\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.6666666666666666, 0.375, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.8888888888888888, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]')]

# %% [markdown]
# # Vorhersage

# %%
# Schritt 8: Nutze das trainierte Modell, um Vorhersagen für die Testdaten zu generieren.

y_predict = model.predict(X_test)

# %% [markdown]
# # Modellbewertung (Accuracy)

# %%
from sklearn.metrics import accuracy_score

# Schritt 9: Berechne die Accuracy basierend auf den Vorhersagen und den Testdaten und vervollständige die 'print()'-Funktion.
accuracy = accuracy_score(y_predict, y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.75
