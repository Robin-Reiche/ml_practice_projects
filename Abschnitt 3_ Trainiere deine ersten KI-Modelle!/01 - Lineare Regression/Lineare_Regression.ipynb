# %% [markdown]
# # Daten importieren

# %%
import pandas as pd

df = pd.read_csv("sales_data.csv")
df
# Out:
#    Website-Traffic  Sales
# 0             1000   1500
# 1             2000   4500
# 2             3000   2500
# 3             4000   5400
# 4             5000   4100
# 5             6000   5100
# 6             7000   6500
# 7             8000   7900
# 8             9000   7800
# 9            10000   9700

# %% [markdown]
# # Daten visualisieren

# %%
import seaborn as sns

sns.scatterplot(x=df["Website-Traffic"], y=df["Sales"])
# Out:
# <Axes: xlabel='Website-Traffic', ylabel='Sales'>

# %% [markdown]
# # Daten aufteilen

# %%
X = df[["Website-Traffic"]]
y = df["Sales"]

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=9)

# %%
X_test
# Out:
#    Website-Traffic
# 8             9000
# 4             5000
# 7             8000

# %%
y_test
# Out:
# 8    7800
# 4    4100
# 7    7900
# Name: Sales, dtype: int64

# %% [markdown]
# # Modell trainieren

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Modell visualisieren

# %%
sns.regplot(x=X_train, y=y_train, ci=None)
# Out:
# <Axes: xlabel='Website-Traffic', ylabel='Sales'>

# %% [markdown]
# # Vorhersage

# %%
X_test
# Out:
#    Website-Traffic
# 8             9000
# 4             5000
# 7             8000

# %%
y_predict = model.predict(X_test)
y_predict
# Out:
# array([8400.48076923, 5253.36538462, 7613.70192308])

# %% [markdown]
# # Modellbewertung (Mean Absolute Error)

# %%
y_test
# Out:
# 8    7800
# 4    4100
# 7    7900
# Name: Sales, dtype: int64

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_predict, y_test)
print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 680.0480769230771

# %% [markdown]
# # Modellparameter

# %%
model.coef_
# Out:
# array([0.78677885])

# %%
m = model.coef_[0]
c = model.intercept_

print("Steigung: ", m)
print("y-Achsenabschnitt: ", c)
# Out:
# Steigung:  0.7867788461538462
# y-Achsenabschnitt:  1319.4711538461534

# %%
print("Vorhersage für 9000:", m * 9000 + c )
# Out:
# Vorhersage für 9000: 8400.48076923077
