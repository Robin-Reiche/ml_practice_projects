# %% [markdown]
# # Daten importieren

# %%
import pandas as pd

df = pd.read_csv("real_estate_data.csv")
df
# Out:
#    Jahresgehalt  Mietvertrag
# 0         50000        False
# 1         35000        False
# 2         70000         True
# 3         45000        False
# 4         30000        False
# 5         65000         True
# 6         60000         True
# 7         55000         True
# 8         40000        False
# 9         75000         True

# %%
df["Mietvertrag"].value_counts()
# Out:
# False    5
# True     5
# Name: Mietvertrag, dtype: int64

# %% [markdown]
# # Daten visualisieren

# %%
import seaborn as sns

sns.scatterplot(x=df["Jahresgehalt"], y=df["Mietvertrag"])
# Out:
# <Axes: xlabel='Jahresgehalt', ylabel='Mietvertrag'>

# %% [markdown]
# # Daten aufteilen

# %%
X = df[["Jahresgehalt"]]
y = df["Mietvertrag"]

# %%
y
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# 6     True
# 7     True
# 8    False
# 9     True
# Name: Mietvertrag, dtype: bool

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=9)

# %%
X_test
# Out:
#    Jahresgehalt
# 8         40000
# 4         30000
# 7         55000

# %%
y_test
# Out:
# 8    False
# 4    False
# 7     True
# Name: Mietvertrag, dtype: bool

# %% [markdown]
# # Modell trainieren

# %%
from sklearn.tree import DecisionTreeClassifier


model = DecisionTreeClassifier()
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# # Modell visualisieren

# %%
from sklearn.tree import plot_tree

plot_tree(model, feature_names=["Jahresgehalt"])
# Out:
# [Text(0.5, 0.75, 'Jahresgehalt <= 55000.0\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]')]

# %% [markdown]
# # Vorhersage

# %%
X_test
# Out:
#    Jahresgehalt
# 8         40000
# 4         30000
# 7         55000

# %%
y_predict = model.predict(X_test)
y_predict
# Out:
# array([False, False, False])

# %% [markdown]
# # Modellbewertung (Accuracy)

# %%
y_test
# Out:
# 8    False
# 4    False
# 7     True
# Name: Mietvertrag, dtype: bool

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_predict, y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.6666666666666666
