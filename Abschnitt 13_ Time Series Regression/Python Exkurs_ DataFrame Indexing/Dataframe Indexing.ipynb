# %%
import pandas as pd

df = pd.read_csv("ford_data.csv")
df
# Out:
#        year  mileage  tax   mpg  engineSize  price
# 0      2017    15944  150  57.7         1.0  12000
# 1      2018     9083  150  57.7         1.0  14000
# 2      2017    12456  150  57.7         1.0  13000
# 3      2019    10460  145  40.3         1.5  17500
# 4      2019     1482  145  48.7         1.0  16500
# ...     ...      ...  ...   ...         ...    ...
# 17961  2017    16700  150  47.1         1.4   8999
# 17962  2014    40700   30  57.7         1.0   7499
# 17963  2015     7010   20  67.3         1.6   9999
# 17964  2018     5007  145  57.7         1.2   8299
# 17965  2015     5007   22  57.7         1.0   8299
#
# [17966 rows x 6 columns]

# %%
df["year"]
# Out:
# 0        2017
# 1        2018
# 2        2017
# 3        2019
# 4        2019
#          ...
# 17961    2017
# 17962    2014
# 17963    2015
# 17964    2018
# 17965    2015
# Name: year, Length: 17966, dtype: int64

# %%
df[["year", "mileage", "tax"]]
# Out:
#        year  mileage  tax
# 0      2017    15944  150
# 1      2018     9083  150
# 2      2017    12456  150
# 3      2019    10460  145
# 4      2019     1482  145
# ...     ...      ...  ...
# 17961  2017    16700  150
# 17962  2014    40700   30
# 17963  2015     7010   20
# 17964  2018     5007  145
# 17965  2015     5007   22
#
# [17966 rows x 3 columns]

# %%
df["year"] > 2017
# Out:
# 0        False
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 17961    False
# 17962    False
# 17963    False
# 17964     True
# 17965    False
# Name: year, Length: 17966, dtype: bool

# %%
new_df = df[df["year"] > 2017]
new_df
# Out:
#        year  mileage  tax   mpg  engineSize  price
# 1      2018     9083  150  57.7         1.0  14000
# 3      2019    10460  145  40.3         1.5  17500
# 4      2019     1482  145  48.7         1.0  16500
# 6      2019     2029  145  50.4         1.0  22500
# 8      2019     6894  145  42.2         2.0  25500
# ...     ...      ...  ...   ...         ...    ...
# 17951  2019     2200  145  51.4         1.0  15999
# 17955  2018     7047  145  48.7         1.0  12500
# 17956  2018     4850  145  47.1         1.0  14750
# 17958  2019    13359  145  48.7         1.0  13250
# 17964  2018     5007  145  57.7         1.2   8299
#
# [7467 rows x 6 columns]

# %%
new_df.iloc[1:4]
# Out:
#    year  mileage  tax   mpg  engineSize  price
# 3  2019    10460  145  40.3         1.5  17500
# 4  2019     1482  145  48.7         1.0  16500
# 6  2019     2029  145  50.4         1.0  22500

# %%
new_df.iloc[[2, 3, 4]]
# Out:
#    year  mileage  tax   mpg  engineSize  price
# 4  2019     1482  145  48.7         1.0  16500
# 6  2019     2029  145  50.4         1.0  22500
# 8  2019     6894  145  42.2         2.0  25500

# %%
new_df.loc[1:4, "mileage":"mpg"]
# Out:
#    mileage  tax   mpg
# 1     9083  150  57.7
# 3    10460  145  40.3
# 4     1482  145  48.7

# %%
new_df.loc[[3, 4], :]
# Out:
#    year  mileage  tax   mpg  engineSize  price
# 3  2019    10460  145  40.3         1.5  17500
# 4  2019     1482  145  48.7         1.0  16500
