# %%
list_of_temperatures_1 = [37, 36, 39, 38]
list_of_temperatures_2 = [40, 37, 39, 36]
list_of_temperatures_3 = [38, 36, 41, 37]

# %%
for temperature in list_of_temperatures_1:
  print(temperature)
# Out:
# 37
# 36
# 39
# 38

# %%
for temperature in list_of_temperatures_2:
  print(temperature)
# Out:
# 40
# 37
# 39
# 36

# %%
for temperature in list_of_temperatures_3:
  print(temperature)
# Out:
# 38
# 36
# 41
# 37

# %%
def print_values(list_of_values):
    for value in list_of_values:
        print(value)

# %%
print_values(list_of_temperatures_1)
# Out:
# 37
# 36
# 39
# 38

# %%
print_values(list_of_temperatures_2)
# Out:
# 40
# 37
# 39
# 36

# %%
print_values(list_of_temperatures_3)
# Out:
# 38
# 36
# 41
# 37

# %%
list_of_names = ["KI", "Machine Learning", "Deep Learning"]

# %%
print_values(list_of_names)
# Out:
# KI
# Machine Learning
# Deep Learning
