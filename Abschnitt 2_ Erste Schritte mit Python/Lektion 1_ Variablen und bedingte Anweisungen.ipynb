# %% [markdown]
# # **Text**

# %%
# Kommentar
x = 5 + 96
print(x)
# Out:
# 101

# %%
body_temperature = 39

# %%
if body_temperature > 38:
  print("Fieber")
else:
  print("Kein Fieber")
# Out:
# Fieber
