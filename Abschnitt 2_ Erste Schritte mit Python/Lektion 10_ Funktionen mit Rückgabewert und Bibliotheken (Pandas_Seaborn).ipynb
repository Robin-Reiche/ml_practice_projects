# %%
salaries = [50000, 35000, 70000, 45000, 30000, 65000, 60000, 55000, 40000, 75000]

# %%
def check_salaries(list_of_salaries, decision_limit):
    for salary in list_of_salaries:
        if salary > 52500:
            print("Ja")
        else:
            print("Nein")

# %%
check_salaries(salaries, 52500)
# Out:
# Nein
# Nein
# Ja
# Nein
# Nein
# Ja
# Ja
# Ja
# Nein
# Ja

# %%
def calculate_square(number):
    return number * number

# %%
result = calculate_square(number=5)
print(result)
# Out:
# 25

# %%
from math import pow

result_2 = pow(5, 2)
print(result_2)
# Out:
# 25.0

# %%
import math as mt

result_3 = mt.pow(5, 3)
print(result_3)
# Out:
# 125.0

# %%
result_3
# Out:
# 125.0

# %%
print("The result is: ", result_3)
# Out:
# The result is:  125.0

# %% [markdown]
# # Pandas Bibliothek

# %%
import pandas as pd

df = pd.read_csv("sales_data.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df["Sales"].max()
# Out:
# 9700

# %%
df
# Out:
#    Website-Traffic  Sales
# 0             1000   1500
# 1             2000   4500
# 2             3000   2500
# 3             4000   5400
# 4             5000   4100
# 5             6000   5100
# 6             7000   6500
# 7             8000   7900
# 8             9000   7800
# 9            10000   9700
