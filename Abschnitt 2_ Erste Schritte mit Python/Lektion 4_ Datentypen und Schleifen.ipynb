# %%
x = "Machine Learning"
print(type(x))
# Out:
# <class 'str'>

# %%
body_temperature = 38
print(type(body_temperature))
# Out:
# <class 'int'>

# %%
result = (body_temperature == 38)
print(type(result))
# Out:
# <class 'bool'>

# %%
list_of_names = ["KI", "Machine Learning", "Deep Learning"]
print(type(list_of_names))
# Out:
# <class 'list'>

# %%
list_of_results = [True, False, True]

# %%
list_of_temperatures = [37, 36, 39, 38]

# %%
print(list_of_temperatures[3])
# Out:
# 38

# %%
for temp in list_of_temperatures:
  print(temp)
# Out:
# 37
# 36
# 39
# 38
